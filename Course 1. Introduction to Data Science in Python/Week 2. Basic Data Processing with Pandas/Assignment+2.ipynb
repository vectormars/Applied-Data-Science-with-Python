# %% [markdown]
# ---
#
# _You are currently looking at **version 1.2** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-data-analysis/resources/0dhYG) course resource._
#
# ---

# %% [markdown]
# # Assignment 2 - Pandas Introduction
# All questions are weighted the same in this assignment.
# ## Part 1
# The following code loads the olympics dataset (olympics.csv), which was derrived from the Wikipedia entry on [All Time Olympic Games Medals](https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table), and does some basic data cleaning.
#
# The columns are organized as # of Summer games, Summer medals, # of Winter games, Winter medals, total # number of games, total # of medals. Use this dataset to answer the questions below.

# %%
import pandas as pd

df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)

for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]}, inplace=True)

names_ids = df.index.str.split('\s\(') # split the index by '('

df.index = names_ids.str[0] # the [0] element is the country name (new index) 
df['ID'] = names_ids.str[1].str[:3] # the [1] element is the abbreviation or ID (take first 3 characters from that)

df = df.drop('Totals')
df.head()
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
# Australasia         2     3       4       5     12         0       0
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Afghanistan         0         0        0       13       0         0         2
# Algeria             0         0        0       15       5         2         8
# Argentina           0         0        0       41      18        24        28
# Armenia             0         0        0       11       1         2         9
# Australasia         0         0        0        2       3         4         5
#
#              Combined total   ID
# Afghanistan               2  AFG
# ...

# %% [markdown]
# ### Question 0 (Example)
#
# What is the first country in df?
#
# *This function should return a Series.*

# %%
# You should write your whole answer within the function provided. The autograder will call
# this function and compare the return value against the correct solution value
def answer_zero():
    # This function returns the row for Afghanistan, which is a Series object. The assignment
    # question description will tell you the general format the autograder is expecting
    return df.iloc[0]

# You can examine what your function returns by calling it in the cell. If you have questions
# about the assignment formats, check out the discussion forums for any FAQs
answer_zero()
# Out:
# # Summer           13
# Gold                0
# Silver              0
# Bronze              2
# Total               2
# # Winter            0
# Gold.1              0
# Silver.1            0
# Bronze.1            0
# Total.1             0
# # Games            13
# Gold.2              0
# Silver.2            0
# Bronze.2            2
# Combined total      2
# ID                AFG
# Name: Afghanistan, dtype: object

# %% [markdown]
# ### Question 1
# Which country has won the most gold medals in summer games?
#
# *This function should return a single string value.*

# %%
df['Gold'].idxmax()
# Out:
# 'United States'

# %%
type(df['Gold'].idxmax())
# Out:
# str

# %%
def answer_one():
    return df['Gold'].idxmax()

# %%
answer_one()
# Out:
# 'United States'

# %% [markdown]
# ### Question 2
# Which country had the biggest difference between their summer and winter gold medal counts?
#
# *This function should return a single string value.*

# %%
maxValue=max(df['Gold']-df['Gold.1'])
df[df['Gold']-df['Gold.1']==maxValue].index[0]
# Out:
# 'United States'

# %%
def answer_two():
    maxValue=max(df['Gold']-df['Gold.1'])
    return df[df['Gold']-df['Gold.1']==maxValue].index[0]

# %% [markdown]
# ### Question 3
# Which country has the biggest difference between their summer gold medal counts and winter gold medal counts relative to their total gold medal count?
#
# $$\frac{Summer~Gold - Winter~Gold}{Total~Gold}$$
#
# Only include countries that have won at least 1 gold in both summer and winter.
#
# *This function should return a single string value.*

# %%
def answer_three():
    df1=df[(df['Gold.1'] > 0) & (df['Gold'] > 0)]
    maxValue=max(abs(df1['Gold']-df1['Gold.1'])/df1['Gold.2'])
    return df1[abs(df1['Gold']-df1['Gold.1'])/df1['Gold.2']==maxValue].index[0]
answer_three()
# Out:
# 'Bulgaria'

# %% [markdown]
# ### Question 4
# Write a function that creates a Series called "Points" which is a weighted value where each gold medal (`Gold.2`) counts for 3 points, silver medals (`Silver.2`) for 2 points, and bronze medals (`Bronze.2`) for 1 point. The function should return only the column (a Series object) which you created.
#
# *This function should return a Series named `Points` of length 146*

# %%
def answer_four():
    Points = 3*df['Gold.2'] + 2*df['Silver.2'] + 1*df['Bronze.2']
    return Points

# %%
len(answer_four())
# Out:
# 146

# %% [markdown]
# ## Part 2
# For the next set of questions, we will be using census data from the [United States Census Bureau](http://www.census.gov/popest/data/counties/totals/2015/CO-EST2015-alldata.html). Counties are political and geographic subdivisions of states in the United States. This dataset contains population data for counties and states in the US from 2010 to 2015. [See this document](http://www.census.gov/popest/data/counties/totals/2015/files/CO-EST2015-alldata.pdf) for a description of the variable names.
#
# The census dataset (census.csv) should be loaded as census_df. Answer questions using this as appropriate.
#
# ### Question 5
# Which state has the most counties in it? (hint: consider the sumlevel key carefully! You'll need this for future questions too...)
#
# *This function should return a single string value.*

# %%
census_df = pd.read_csv('census.csv')
census_df.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0        4779736            4780127          4785161     ...
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0          0.002295         -0.193196          0.381066          0.582002
# ...

# %%
census_df.shape
# Out:
# (3193, 100)

# %%
census_df[census_df['STNAME']=='Alabama']['CTYNAME'].count()
# Out:
# 68

# %%
census_df_grouped=census_df[['STNAME','CTYNAME']].groupby(['STNAME']).agg(['count'])
print(census_df_grouped)
# Out:
#                      CTYNAME
#                        count
# STNAME
# Alabama                   68
# Alaska                    30
# Arizona                   16
# Arkansas                  76
# California                59
# Colorado                  65
# Connecticut                9
# Delaware                   4
# District of Columbia       2
# Florida                   68
# Georgia                  160
# Hawaii                     6
# Idaho                     45
# Illinois                 103
# Indiana                   93
# Iowa                     100
# Kansas                   106
# Kentucky                 121
# Louisiana                 65
# Maine                     17
# Maryland                  25
# Massachusetts             15
# Michigan                  84
# Minnesota                 88
# Mississippi               83
# Missouri                 116
# Montana                   57
# Nebraska                  94
# Nevada                    18
# ...

# %%
census_df_grouped.max()
# Out:
# CTYNAME  count    255
# dtype: int64

# %%
type(census_df_grouped)
# Out:
# pandas.core.frame.DataFrame

# %%
census_df_grouped.idxmax()[0]
# Out:
# 'Texas'

# %%
def answer_five():
    census_df_grouped=census_df[['STNAME','CTYNAME']].groupby(['STNAME']).agg(['count'])
    return census_df_grouped.idxmax()[0]

# %%
answer_five()
# Out:
# 'Texas'

# %% [markdown]
# ### Question 6
# Only looking at the three most populous counties for each state, what are the three most populous states (in order of highest population to lowest population)? Use `CENSUS2010POP`.
#
# *This function should return a list of string values.*

# %% [markdown]
# #### Part 1

# %%
census_df_pop=census_df[['STNAME','CTYNAME','CENSUS2010POP']].groupby(['STNAME'])
# census_df_pop.groups
type(census_df_pop)
# Out:
# pandas.core.groupby.DataFrameGroupBy

# %%
census_df_pop.get_group('Alabama').head()
# Out:
#     STNAME         CTYNAME  CENSUS2010POP
# 0  Alabama         Alabama        4779736
# 1  Alabama  Autauga County          54571
# 2  Alabama  Baldwin County         182265
# 3  Alabama  Barbour County          27457
# 4  Alabama     Bibb County          22915

# %%
type(census_df_pop.get_group('Alabama'))
# Out:
# pandas.core.frame.DataFrame

# %%
census_df_pop_group=census_df_pop.get_group('Alabama')
census_df_pop_group['CTYNAME'][census_df_pop_group['CENSUS2010POP'].idxmax()]
# Out:
# 'Alabama'

# %%
census_df_pop_group.sort('CENSUS2010POP',ascending=False).head(3)
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#      STNAME           CTYNAME  CENSUS2010POP
# 0   Alabama           Alabama        4779736
# 37  Alabama  Jefferson County         658466
# 49  Alabama     Mobile County         412992

# %%
census_df_pop_group.sort('CENSUS2010POP',ascending=False)[0:3]['CENSUS2010POP'].sum()
# Out:
# /opt/conda/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
# 5851194

# %% [markdown]
# #### Part 2

# %%
census_df.shape
# Out:
# (3193, 100)

# %%
cdf = census_df[census_df['SUMLEV'] == 50]
cdf.shape
# Out:
# (3142, 100)

# %%
cdf =cdf.groupby('STNAME')
cdf = cdf.apply(lambda x:x.sort_values('CENSUS2010POP', ascending=False))
print(cdf.shape)
cdf.head()
# Out:
# (3142, 100)
#             SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME  \
# STNAME
# Alabama 37      50       3         6      1      73  Alabama
#         49      50       3         6      1      97  Alabama
#         45      50       3         6      1      89  Alabama
#         51      50       3         6      1     101  Alabama
#         59      50       3         6      1     117  Alabama
#
#                       CTYNAME  CENSUS2010POP  ESTIMATESBASE2010  \
# STNAME
# Alabama 37   Jefferson County         658466             658350
#         49      Mobile County         412992             413143
#         45     Madison County         334811             334811
#         51  Montgomery County         229363             229363
#         59      Shelby County         195085             195218
#
#             POPESTIMATE2010     ...       RDOMESTICMIG2011  RDOMESTICMIG2012  \
# STNAME                          ...
# ...

# %%
cdf=cdf.reset_index(drop=True)
print(cdf.shape)
cdf.head()
# Out:
# (3142, 100)
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME            CTYNAME  \
# 0      50       3         6      1      73  Alabama   Jefferson County
# 1      50       3         6      1      97  Alabama      Mobile County
# 2      50       3         6      1      89  Alabama     Madison County
# 3      50       3         6      1     101  Alabama  Montgomery County
# 4      50       3         6      1     117  Alabama      Shelby County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 0         658466             658350           658116     ...
# 1         412992             413143           413332     ...
# 2         334811             334811           336138     ...
# 3         229363             229363           229723     ...
# 4         195085             195218           196048     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 0         -4.138628         -4.492646         -1.664873         -0.970225
# ...

# %%
cdf = cdf.groupby('STNAME').head(3)
print(cdf.shape)
cdf.head(10)
# Out:
# (151, 100)
#      SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME  \
# 0        50       3         6      1      73   Alabama
# 1        50       3         6      1      97   Alabama
# 2        50       3         6      1      89   Alabama
# 67       50       4         9      2      20    Alaska
# 68       50       4         9      2      90    Alaska
# 69       50       4         9      2     170    Alaska
# 96       50       4         8      4      13   Arizona
# 97       50       4         8      4      19   Arizona
# 98       50       4         8      4      21   Arizona
# 111      50       3         7      5     119  Arkansas
#
#                           CTYNAME  CENSUS2010POP  ESTIMATESBASE2010  \
# 0                Jefferson County         658466             658350
# 1                   Mobile County         412992             413143
# 2                  Madison County         334811             334811
# 67         Anchorage Municipality         291826             291826
# ...

# %%
cdf=cdf.groupby('STNAME').sum()
print(cdf.shape)
cdf.head(10)
# Out:
# (51, 98)
#                       SUMLEV  REGION  DIVISION  STATE  COUNTY  CENSUS2010POP  \
# STNAME
# Alabama                  150       9        18      3     259        1406269
# Alaska                   150      12        27      6     280         478402
# Arizona                  150      12        24     12      53        5173150
# Arkansas                 150       9        21     15     269         807152
# California               150      12        27     18     169       15924150
# Colorado                 150      12        24     24      77        1794424
# Connecticut              150       3         3     27      13        2673320
# Delaware                 150       9        15     30       9         897934
# District of Columbia      50       3         5     11       1         601723
# Florida                  150       9        15     36     196        5564635
#
#                       ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# STNAME
# ...

# %%
cdf = cdf.sort_values('CENSUS2010POP', axis=0, ascending=False).head(3)
print(cdf.shape)
cdf.head()
# Out:
# (3, 98)
#             SUMLEV  REGION  DIVISION  STATE  COUNTY  CENSUS2010POP  \
# STNAME
# California     150      12        27     18     169       15924150
# Texas          150       9        21    144     753        8269632
# Illinois       150       6         9     51     171        6815061
#
#             ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  \
# STNAME
# California           15924274         15948261         16094942
# Texas                 8270250          8298179          8439027
# Illinois              6815323          6821742          6841179
#
#             POPESTIMATE2012     ...       RDOMESTICMIG2011  RDOMESTICMIG2012  \
# STNAME                          ...
# California         16244137     ...              -2.651916         -3.217407
# Texas               8601286     ...               7.142972         14.863483
# Illinois            6862181     ...             -19.864534        -18.494617
#
# ...

# %%
cdf.index.tolist()
# Out:
# ['California', 'Texas', 'Illinois']

# %%
def answer_six():
    cdf = census_df[census_df['SUMLEV'] == 50]
    cdf =cdf.groupby('STNAME')
    cdf = cdf.apply(lambda x:x.sort_values('CENSUS2010POP', ascending=False))
    cdf=cdf.reset_index(drop=True)
    cdf = cdf.groupby('STNAME').head(3)
    cdf=cdf.groupby('STNAME').sum()
    cdf = cdf.sort_values('CENSUS2010POP', axis=0, ascending=False).head(3)
    return cdf.index.tolist()

# %%
answer_six()
# Out:
# ['California', 'Texas', 'Illinois']

# %% [markdown]
# ### Question 7
# Which county has had the largest absolute change in population within the period 2010-2015? (Hint: population values are stored in columns POPESTIMATE2010 through POPESTIMATE2015, you need to consider all six columns.)
#
# e.g. If County Population in the 5 year period is 100, 120, 80, 105, 100, 130, then its largest change in the period would be |130-80| = 50.
#
# *This function should return a single string value.*

# %%
cdf=census_df.copy()
cdf = cdf[cdf['SUMLEV'] == 50]
cdf['Largest change']=cdf[['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']].max(axis=1)-cdf[['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']].min(axis=1)
cdf.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010       ...        \
# 1          54571              54571            54660       ...
# 2         182265             182265           183193       ...
# 3          27457              27457            27341       ...
# 4          22915              22919            22861       ...
# 5          57322              57322            57373       ...
#
#    RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 1         -2.915927         -3.012349          2.265971         -2.530799
# ...

# %%
cdf.sort_values('Largest change', axis=0, ascending=False).head()
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY      STNAME             CTYNAME  \
# 2667      50       3         7     48     201       Texas       Harris County
# 209       50       4         9      6      37  California  Los Angeles County
# 106       50       4         8      4      13     Arizona     Maricopa County
# 227       50       4         9      6      73  California    San Diego County
# 372       50       3         5     12      86     Florida   Miami-Dade County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010       ...        \
# 2667        4092459            4093076          4108187       ...
# 209         9818605            9818700          9826009       ...
# 106         3817117            3817357          3825597       ...
# 227         3095313            3095308          3104386       ...
# 372         2496435            2498017          2508171       ...
#
#       RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# ...

# %%
cdf=cdf.sort_values('Largest change', axis=0, ascending=False).head(1)
cdf
# Out:
#       SUMLEV  REGION  DIVISION  STATE  COUNTY STNAME        CTYNAME  \
# 2667      50       3         7     48     201  Texas  Harris County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010       ...        \
# 2667        4092459            4093076          4108187       ...
#
#       RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  RDOMESTICMIG2015  \
# 2667          3.518819          4.820913          5.243613          3.794291
#
#       RNETMIG2011  RNETMIG2012  RNETMIG2013  RNETMIG2014  RNETMIG2015  \
# 2667     7.154417     8.915715    10.683269    11.850629    10.303814
#
#       Largest change
# 2667          429841
#
# [1 rows x 101 columns]

# %%
cdf.iloc[0]['CTYNAME']
# Out:
# 'Harris County'

# %%
def answer_seven():
    cdf=census_df.copy()
    cdf = cdf[cdf['SUMLEV'] == 50]
    cdf['Largest change']=cdf[['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']].max(axis=1)-cdf[['POPESTIMATE2010','POPESTIMATE2011','POPESTIMATE2012','POPESTIMATE2013','POPESTIMATE2014','POPESTIMATE2015']].min(axis=1)
    cdf=cdf.sort_values('Largest change', axis=0, ascending=False).head(1)
    return cdf.iloc[0]['CTYNAME']

# %%
answer_seven()
# Out:
# 'Harris County'

# %% [markdown]
# ### Question 8
# In this datafile, the United States is broken up into four regions using the "REGION" column.
#
# Create a query that finds the counties that belong to regions 1 or 2, whose name starts with 'Washington', and whose POPESTIMATE2015 was greater than their POPESTIMATE 2014.
#
# *This function should return a 5x2 DataFrame with the columns = ['STNAME', 'CTYNAME'] and the same index ID as the census_df (sorted ascending by index).*

# %%
cdf = census_df.copy()
cdf = cdf[cdf['SUMLEV'] == 50]
print(cdf.shape)
cdf.head()
# Out:
# (3142, 100)
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
# 5      50       3         6      1       9  Alabama   Blount County
#
#    CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 1          54571              54571            54660     ...
# 2         182265             182265           183193     ...
# 3          27457              27457            27341     ...
# 4          22915              22919            22861     ...
# 5          57322              57322            57373     ...
#
#    RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# 1          7.242091         -2.915927         -3.012349          2.265971
# ...

# %%
cdf=cdf[(cdf['REGION']==1) | (cdf['REGION']==2)]
print(cdf.shape)
cdf.head()
# Out:
# (1272, 100)
#      SUMLEV  REGION  DIVISION  STATE  COUNTY       STNAME            CTYNAME  \
# 315      50       1         1      9       1  Connecticut   Fairfield County
# 316      50       1         1      9       3  Connecticut    Hartford County
# 317      50       1         1      9       5  Connecticut  Litchfield County
# 318      50       1         1      9       7  Connecticut   Middlesex County
# 319      50       1         1      9       9  Connecticut   New Haven County
#
#      CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 315         916829             916850           919744     ...
# 316         894014             894029           895303     ...
# 317         189927             189927           189773     ...
# 318         165676             165676           165628     ...
# 319         862477             862474           863401     ...
#
#      RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# ...

# %%
cdf=cdf[cdf['CTYNAME'].str.contains('Washington')]
print(cdf.shape)
cdf.head()
# Out:
# (14, 100)
#       SUMLEV  REGION  DIVISION  STATE  COUNTY    STNAME            CTYNAME  \
# 703       50       2         3     17     189  Illinois  Washington County
# 799       50       2         3     18     175   Indiana  Washington County
# 896       50       2         4     19     183      Iowa  Washington County
# 1005      50       2         4     20     201    Kansas  Washington County
# 1211      50       1         1     23      29     Maine  Washington County
#
#       CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010     ...       \
# 703           14716              14716            14701     ...
# 799           28262              28262            28284     ...
# 896           21704              21704            21697     ...
# 1005           5799               5799             5782     ...
# 1211          32856              32856            32824     ...
#
#       RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  RDOMESTICMIG2014  \
# ...

# %%
cdf=cdf[cdf['POPESTIMATE2015']>cdf['POPESTIMATE2014']]
print(cdf.shape)
cdf.head()
# Out:
# (5, 100)
#       SUMLEV  REGION  DIVISION  STATE  COUNTY        STNAME  \
# 896       50       2         4     19     183          Iowa
# 1419      50       2         4     27     163     Minnesota
# 2345      50       1         2     42     125  Pennsylvania
# 2355      50       1         1     44       9  Rhode Island
# 3163      50       2         3     55     131     Wisconsin
#
#                 CTYNAME  CENSUS2010POP  ESTIMATESBASE2010  POPESTIMATE2010  \
# 896   Washington County          21704              21704            21697
# 1419  Washington County         238136             238134           238995
# 2345  Washington County         207820             207820           207877
# 2355  Washington County         126979             127094           127085
# 3163  Washington County         131887             131885           131967
#
#          ...       RDOMESTICMIG2011  RDOMESTICMIG2012  RDOMESTICMIG2013  \
# ...

# %%
cdf[['STNAME','CTYNAME']]
# Out:
#             STNAME            CTYNAME
# 896           Iowa  Washington County
# 1419     Minnesota  Washington County
# 2345  Pennsylvania  Washington County
# 2355  Rhode Island  Washington County
# 3163     Wisconsin  Washington County

# %%
def answer_eight():
    cdf = census_df.copy()
    cdf = cdf[cdf['SUMLEV'] == 50]
    cdf=cdf[(cdf['REGION']==1) | (cdf['REGION']==2)]
    cdf=cdf[cdf['CTYNAME'].str.contains('Washington')]
    cdf=cdf[cdf['POPESTIMATE2015']>cdf['POPESTIMATE2014']]
    return cdf[['STNAME','CTYNAME']]

# %%
answer_eight()
# Out:
#             STNAME            CTYNAME
# 896           Iowa  Washington County
# 1419     Minnesota  Washington County
# 2345  Pennsylvania  Washington County
# 2355  Rhode Island  Washington County
# 3163     Wisconsin  Washington County
